# %% [markdown]
# ## ReplicaSets
#
# In this notebook, we look at Kubernetes ReplicaSets.
#
# - Make sure you have a Kubernetes cluster (Docker Desktop) running.
# - Also make sure you have installed the `kubectl` tool on your computer.

# %% [markdown]
# ## Create a ReplicaSet called `rs-example`
#
# - The ReplicaSet definition is in the YAML file `manifests/rs-example-yaml`.

# %%
# !kubectl apply -f manifests/rs-example.yaml
# Out:
# replicaset.apps/rs-example created

# %% [markdown]
# ## Let's look at the ReplicaSet's YAML
#
# **Note:**
#
# - The number of replicas is set to 3.
# - The ReplicaSet's matchLabels match the Pod template's labels.
# - The Pod template's containers are based on the nginx image.
# - The Pod template's containers are listening on port 80.
#
# ```bash
# apiVersion: apps/v1
# kind: ReplicaSet
# metadata:
#   name: rs-example           # the replicaset's name
# spec:
#   replicas: 3                # the number of replicas
#   selector:
#     matchLabels:
#       app: nginx             # the replicaset's matchLabels are defined as (and match the Pod template's labels below):
#       type: front-end        # app = nginx and type = front-end
#   template:
#     metadata:
#       labels:
#         app: nginx           # the Pod template's labels are defined as:
#         type: front-end      # app = nginx and type = front-end
#     spec:
#       containers:
#       - name: nginx          # the container's name
#         image: nginx:alpine  # the image the container is based on
#         resources:
#           requests:
#             cpu: 100m
#             memory: 128Mi
#           limits:
#             cpu: 250m
#             memory: 256Mi
#         ports:
#         - containerPort: 80   # the container is listening on port 80
# ```

# %%
# !type manifests\rs-example.yaml
#!cat manifests/rs-example.yaml# use this in Linux/Mac
# Out:
# apiVersion: apps/v1
# kind: ReplicaSet
# metadata:
#   name: rs-example
# spec:
#   replicas: 3
#   selector:
#     matchLabels:
#       app: nginx
#       type: front-end
#   template:
#     metadata:
#       labels:
#         app: nginx
#         type: front-end
#     spec:
#       containers:
#       - name: nginx
#         image: nginx:alpine
#         resources:
#           requests:
#             cpu: 100m
#             memory: 128Mi
#           limits:
#             cpu: 250m
#             memory: 256Mi
#         ports:
#         - containerPort: 80

# %% [markdown]
# ## List Pods
#
# - Notice the name of each Pod replica consists of the ReplicaSet name `rs-example` and a randomly generated suffix.

# %%
#!kubectl get po -o wide
# !kubectl get pods -o wide
# Out:
# NAME               READY   STATUS    RESTARTS   AGE   IP         NODE             NOMINATED NODE   READINESS GATES
# rs-example-cglw6   1/1     Running   0          64s   10.1.1.4   docker-desktop   <none>           <none>
# rs-example-gfccf   1/1     Running   0          64s   10.1.1.3   docker-desktop   <none>           <none>
# rs-example-k7l2m   1/1     Running   0          64s   10.1.1.5   docker-desktop   <none>           <none>

# %% [markdown]
# ## List ReplicaSets
#
# - Notice the current number of replicas is the same as the desired number of replicas (and they are all ready).

# %%
#!kubectl get rs -o wide
# !kubectl get replicasets -o wide
# Out:
# NAME         DESIRED   CURRENT   READY   AGE   CONTAINERS   IMAGES         SELECTOR
# rs-example   3         3         3       71s   nginx        nginx:alpine   app=nginx,type=front-end

# %% [markdown]
# ## Describe the ReplicaSet (detailed info.)
#
# - Notice the `Pods Status` tells us 3 Pod replicas are running.

# %%
#!kubectl describe rs rs-example
# !kubectl describe replicaset rs-example
# Out:
# Name:         rs-example
# Namespace:    default
# Selector:     app=nginx,type=front-end
# Labels:       <none>
# Annotations:  <none>
# Replicas:     3 current / 3 desired
# Pods Status:  3 Running / 0 Waiting / 0 Succeeded / 0 Failed
# Pod Template:
#   Labels:  app=nginx
#            type=front-end
#   Containers:
#    nginx:
#     Image:      nginx:alpine
#     Port:       80/TCP
#     Host Port:  0/TCP
#     Limits:
#       cpu:     250m
#       memory:  256Mi
#     Requests:
#       cpu:         100m
#       memory:      128Mi
#     Environment:   <none>
#     Mounts:        <none>
#   Volumes:         <none>
#   Node-Selectors:  <none>
#   Tolerations:     <none>
# Events:
#   Type    Reason            Age   From                   Message
#   ----    ------            ----  ----                   -------
#   Normal  SuccessfulCreate  81s   replicaset-controller  Created pod: rs-example-gfccf
#   Normal  SuccessfulCreate  81s   replicaset-controller  Created pod: rs-example-k7l2m
#   Normal  SuccessfulCreate  81s   replicaset-controller  Created pod: rs-example-cglw6

# %% [markdown]
# ## Delete the ReplicaSet

# %%
# !kubectl delete -f manifests/rs-example.yaml
# Out:
# replicaset.apps "rs-example" deleted

# %% [markdown]
# ## List ReplicaSets and Pods
#
# - We see the ReplicaSet and Pods have been deleted.

# %%
#!kubectl get rs
#!kubectl get po
# !kubectl get replicasets
# !kubectl get pods
# Out:
# No resources found in default namespace.
# No resources found in default namespace.
