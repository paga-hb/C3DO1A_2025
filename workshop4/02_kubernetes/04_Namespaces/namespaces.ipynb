# %% [markdown]
# ## Namespaces
#
# In this notebook, we look at Kubernetes namespaces.
#
# - Make sure you have a Kubernetes cluster (Docker Desktop) running.
# - Also make sure you have installed the `kubectl` tool on your computer.

# %% [markdown]
# ## List Namespaces
#
# - A namespace is used to group resources logically in a kubernetes cluster.
# - The command `kubectl get namesapces` returns all namespaces in the kubernetes cluster.
#   - In this case the cluster contains 4 namespaces.

# %%
#!kubectl get ns
# !kubectl get namespaces
# Out:
# NAME                   STATUS   AGE
# default                Active   24d
# kube-node-lease        Active   24d
# kube-public            Active   24d
# kube-system            Active   24d
# kubernetes-dashboard   Active   128m

# %% [markdown]
# ## List Pods in the current namespace
#
# - The **current namespace** is the namespace `kubectl` uses if no namespace is explicitly specified in a command.
#   - By default the **current namespace** is set to the `default` namespace.
#
# - The command `kubectl get pods` is used to list Pods running in a kubernetes cluster.
#   - The `-o wide` option returns additional information.
# - Only the Pods in the `default` namespace are shown (since `default` is the current namespace).
#   - If we don't explicitly ask for a specific namespace, the current namespace is assumed.
#   - In this case, there are no Pods running in the `default` namespace.

# %%
#!kubectl get pods
# !kubectl get pods -o wide
# Out:
# No resources found in default namespace.

# %% [markdown]
# ## List Pods in a specific namespace
#
# - We can explicitly state which namespace we are interested in with the `--namespace` option.
# - In this case we are listing Pods running in namespace `kube-system`.
#   - Namespace `kube-system` contains resouces used internally by the kubernetes system such as Control Plane Pods.

# %%
#!kubectl get pods -n kube-system -o wide
# !kubectl get pods --namespace=kube-system -o wide
# Out:
# NAME                                     READY   STATUS    RESTARTS       AGE   IP             NODE             NOMINATED NODE   READINESS GATES
# coredns-55cb58b774-67kt4                 1/1     Running   19 (12h ago)   24d   10.1.0.211     docker-desktop   <none>           <none>
# coredns-55cb58b774-lqndz                 1/1     Running   19 (12h ago)   24d   10.1.0.212     docker-desktop   <none>           <none>
# etcd-docker-desktop                      1/1     Running   19 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-apiserver-docker-desktop            1/1     Running   19 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-controller-manager-docker-desktop   1/1     Running   19 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-proxy-9d8nz                         1/1     Running   19 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-scheduler-docker-desktop            1/1     Running   23 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# metrics-server-869cd9f57-4qx4k           1/1     Running   0              47m   10.1.0.244     docker-desktop   <none>           <none>
# storage-provisioner                      1/1     Running   41 (12h ago)   24d   10.1.0.209     docker-desktop   <none>           <none>
# vpnkit-controller                        1/1     Running   19 (12h ago)   24d   10.1.0.210     docker-desktop   <none>           <none>

# %% [markdown]
# ## List Pods in all namespaces
#
# - We can list Pods running in all namespaces with the `--all-namespaces` option.

# %%
#!kubectl get pods -A -o wide
# !kubectl get pods --all-namespaces -o wide
# Out:
# NAMESPACE              NAME                                                    READY   STATUS    RESTARTS       AGE   IP             NODE             NOMINATED NODE   READINESS GATES
# kube-system            coredns-55cb58b774-67kt4                                1/1     Running   19 (12h ago)   24d   10.1.0.211     docker-desktop   <none>           <none>
# kube-system            coredns-55cb58b774-lqndz                                1/1     Running   19 (12h ago)   24d   10.1.0.212     docker-desktop   <none>           <none>
# kube-system            etcd-docker-desktop                                     1/1     Running   19 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-system            kube-apiserver-docker-desktop                           1/1     Running   19 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-system            kube-controller-manager-docker-desktop                  1/1     Running   19 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-system            kube-proxy-9d8nz                                        1/1     Running   19 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-system            kube-scheduler-docker-desktop                           1/1     Running   23 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-system            metrics-server-869cd9f57-4qx4k                          1/1     Running   0              47m   10.1.0.244     docker-desktop   <none>           <none>
# kube-system            storage-provisioner                                     1/1     Running   41 (12h ago)   24d   10.1.0.209     docker-desktop   <none>           <none>
# kube-system            vpnkit-controller                                       1/1     Running   19 (12h ago)   24d   10.1.0.210     docker-desktop   <none>           <none>
# kubernetes-dashboard   kubernetes-dashboard-api-8c47764c-982dh                 1/1     Running   0              47m   10.1.0.247     docker-desktop   <none>           <none>
# kubernetes-dashboard   kubernetes-dashboard-auth-86789567b4-92dwx              1/1     Running   0              47m   10.1.0.245     docker-desktop   <none>           <none>
# kubernetes-dashboard   kubernetes-dashboard-kong-78fd98d579-2nqbr              1/1     Running   0              47m   10.1.0.248     docker-desktop   <none>           <none>
# kubernetes-dashboard   kubernetes-dashboard-metrics-scraper-6c8d6bb74d-6qrz6   1/1     Running   0              47m   10.1.0.246     docker-desktop   <none>           <none>
# kubernetes-dashboard   kubernetes-dashboard-web-86495b6c8f-b8z85               1/1     Running   0              47m   10.1.0.249     docker-desktop   <none>           <none>

# %% [markdown]
# ## Change the current namespace
#
# - We can change the current namespace setting in kubectl's `config` file:
#   - The command `kubectl config set-context --current --namespace=[NamespaceName]` does this.
#     - `[NamespaceName]` is the name of the namespace we want to set as the current namespace.
#     - In this case we are choosing namespace `kube-system`.

# %%
# !kubectl config set-context --current --namespace=kube-system
# Out:
# Context "docker-desktop" modified.

# %% [markdown]
# ## Get current namespace
#
# - We can use the command `kubectl config view` to view the contents of the kubectl configuration file.
#   - The `--minify` flag makes the output less verbose.
#   - The `-o jsonpath` flag can be used to parse the JSON output.
#     - In this case we are only extracting the current namespace associated with the current context `docker-dashboard`.
# - We see the current namespace is now the `kube-system` namespace.

# %%
# !kubectl config view --minify -o jsonpath="{..namespace}{\"\n\"}"
# Out:
# kube-system

# %% [markdown]
# ## List pods in the current namespace
#
# - Now if we list the Pods without explicitly specifying a namespace, the namespace `kube-system` is assumed.
#   - Since the current namespace is now the `kube-system` namespace.

# %%
#!kubectl get pods
# !kubectl get pods -o wide
# Out:
# NAME                                     READY   STATUS    RESTARTS       AGE   IP             NODE             NOMINATED NODE   READINESS GATES
# coredns-55cb58b774-67kt4                 1/1     Running   19 (12h ago)   24d   10.1.0.211     docker-desktop   <none>           <none>
# coredns-55cb58b774-lqndz                 1/1     Running   19 (12h ago)   24d   10.1.0.212     docker-desktop   <none>           <none>
# etcd-docker-desktop                      1/1     Running   19 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-apiserver-docker-desktop            1/1     Running   19 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-controller-manager-docker-desktop   1/1     Running   19 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-proxy-9d8nz                         1/1     Running   19 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# kube-scheduler-docker-desktop            1/1     Running   23 (12h ago)   24d   192.168.65.3   docker-desktop   <none>           <none>
# metrics-server-869cd9f57-4qx4k           1/1     Running   0              54m   10.1.0.244     docker-desktop   <none>           <none>
# storage-provisioner                      1/1     Running   41 (12h ago)   24d   10.1.0.209     docker-desktop   <none>           <none>
# vpnkit-controller                        1/1     Running   19 (12h ago)   24d   10.1.0.210     docker-desktop   <none>           <none>

# %% [markdown]
# ## Change the current namespace back to `default`
#
# - Let's change the current namespace back to the `default` namespace.

# %%
# !kubectl config set-context --current --namespace=default
# Out:
# Context "docker-desktop" modified.

# %% [markdown]
# ## Get current namespace
#
# - We see the current namespace is now the `default` namespace.

# %%
# !kubectl config view --minify -o jsonpath="{..namespace}{\"\n\"}"
# Out:
# default

# %% [markdown]
# ## List pods in the current namespace
#
# - Now if we list the Pods without explicitly specifying a namespace, the namespace `default` is assumed.
#   - Since the current namespace is now the `default` namespace.

# %%
#!kubectl get pods
# !kubectl get pods -o wide
# Out:
# No resources found in default namespace.

# %% [markdown]
# ## Create a Namespace
#
# - The command `kubectl create namespace [NamespaceName]` creates a namespace with the name `[NamespaceName]`.
# - Here we are creating the namespace `my-namespace`.

# %%
#!kubectl create ns my-namespace
# !kubectl create namespace my-namespace
# Out:
# namespace/my-namespace created

# %% [markdown]
# ## List Namespaces
#
# - We see that the new namespace has been created.

# %%
# !kubectl get ns
# Out:
# NAME                   STATUS   AGE
# default                Active   24d
# kube-node-lease        Active   24d
# kube-public            Active   24d
# kube-system            Active   24d
# kubernetes-dashboard   Active   145m
# my-namespace           Active   5s

# %% [markdown]
# ## Create a resource in a specific namespace
#
# - We can create a resource in a specific namespace by using the `--namespace` (or `-n`) option.
# - Let's create a `deployment` in namespace `my-namespace`.

# %%
# !kubectl create deployment mynginx --image=nginx --namespace my-namespace
# Out:
# deployment.apps/mynginx created

# %% [markdown]
# ## List Deployments in all namespaces
#
# - We see our `mynginx` deployment was created in namespace `my-namespace`.

# %%
#!kubectl get deployments -A
# !kubectl get deployments --all-namespaces
# Out:
# NAMESPACE              NAME                                   READY   UP-TO-DATE   AVAILABLE   AGE
# kube-system            coredns                                2/2     2            2           24d
# kube-system            metrics-server                         1/1     1            1           56m
# kubernetes-dashboard   kubernetes-dashboard-api               1/1     1            1           56m
# kubernetes-dashboard   kubernetes-dashboard-auth              1/1     1            1           56m
# kubernetes-dashboard   kubernetes-dashboard-kong              1/1     1            1           56m
# kubernetes-dashboard   kubernetes-dashboard-metrics-scraper   1/1     1            1           56m
# kubernetes-dashboard   kubernetes-dashboard-web               1/1     1            1           56m
# my-namespace           mynginx                                1/1     1            1           9s

# %% [markdown]
# ## Delete Namespace
#
# - The command `kubectl delete namespace [NamespaceName]` deletes the namespace with name `[NameSpaceName]`.
# - Here we are deleting the namespace `my-namespace`.
# - **Note! Deleting a namespace will delete all resources contained in the namespace.**

# %%
#!kubectl delete ns my-namespace
# !kubectl delete namespace my-namespace
# Out:
# namespace "my-namespace" deleted

# %% [markdown]
# ## List Namespaces
#
# - We see that the namespace has been deleted.

# %%
# !kubectl get ns
# Out:
# NAME                   STATUS   AGE
# default                Active   24d
# kube-node-lease        Active   24d
# kube-public            Active   24d
# kube-system            Active   24d
# kubernetes-dashboard   Active   146m

# %% [markdown]
# ## List Deployments in all namespaces
#
# - We see our `mynginx` deployment was deleted when we deleted namespace `my-namespace`.
#   - Since namespace `my-namespace` contained deployment `mynginx`.

# %%
#!kubectl get deployments -A
# !kubectl get deployments --all-namespaces
# Out:
# NAMESPACE              NAME                                   READY   UP-TO-DATE   AVAILABLE   AGE
# kube-system            coredns                                2/2     2            2           24d
# kube-system            metrics-server                         1/1     1            1           57m
# kubernetes-dashboard   kubernetes-dashboard-api               1/1     1            1           57m
# kubernetes-dashboard   kubernetes-dashboard-auth              1/1     1            1           57m
# kubernetes-dashboard   kubernetes-dashboard-kong              1/1     1            1           57m
# kubernetes-dashboard   kubernetes-dashboard-metrics-scraper   1/1     1            1           57m
# kubernetes-dashboard   kubernetes-dashboard-web               1/1     1            1           57m

# %% [markdown]
# ## List all resources in all namespaes
#
# - The command `kubectl get all --all-namespaces` lists all resources in all namespaces.

# %%
#!kubectl get all -A
# !kubectl get all --all-namespaces
# Out:
# NAMESPACE              NAME                                                        READY   STATUS    RESTARTS       AGE
# kube-system            pod/coredns-55cb58b774-67kt4                                1/1     Running   19 (12h ago)   24d
# kube-system            pod/coredns-55cb58b774-lqndz                                1/1     Running   19 (12h ago)   24d
# kube-system            pod/etcd-docker-desktop                                     1/1     Running   19 (12h ago)   24d
# kube-system            pod/kube-apiserver-docker-desktop                           1/1     Running   19 (12h ago)   24d
# kube-system            pod/kube-controller-manager-docker-desktop                  1/1     Running   19 (12h ago)   24d
# kube-system            pod/kube-proxy-9d8nz                                        1/1     Running   19 (12h ago)   24d
# kube-system            pod/kube-scheduler-docker-desktop                           1/1     Running   23 (12h ago)   24d
# kube-system            pod/metrics-server-869cd9f57-4qx4k                          1/1     Running   0              57m
# kube-system            pod/storage-provisioner                                     1/1     Running   41 (12h ago)   24d
# kube-system            pod/vpnkit-controller                                       1/1     Running   19 (12h ago)   24d
# kubernetes-dashboard   pod/kubernetes-dashboard-api-8c47764c-982dh                 1/1     Running   0              57m
# kubernetes-dashboard   pod/kubernetes-dashboard-auth-86789567b4-92dwx              1/1     Running   0              57m
# kubernetes-dashboard   pod/kubernetes-dashboard-kong-78fd98d579-2nqbr              1/1     Running   0              57m
# kubernetes-dashboard   pod/kubernetes-dashboard-metrics-scraper-6c8d6bb74d-6qrz6   1/1     Running   0              57m
# kubernetes-dashboard   pod/kubernetes-dashboard-web-86495b6c8f-b8z85               1/1     Running   0              57m
#
# NAMESPACE              NAME                                           TYPE        CLUSTER-IP       EXTERNAL-IP   PORT(S)                  AGE
# default                service/kubernetes                             ClusterIP   10.96.0.1        <none>        443/TCP                  24d
# kube-system            service/kube-dns                               ClusterIP   10.96.0.10       <none>        53/UDP,53/TCP,9153/TCP   24d
# kube-system            service/metrics-server                         ClusterIP   10.102.8.194     <none>        443/TCP                  57m
# kubernetes-dashboard   service/kubernetes-dashboard-api               ClusterIP   10.105.125.68    <none>        8000/TCP                 57m
# kubernetes-dashboard   service/kubernetes-dashboard-auth              ClusterIP   10.110.86.223    <none>        8000/TCP                 57m
# kubernetes-dashboard   service/kubernetes-dashboard-kong-proxy        ClusterIP   10.105.146.17    <none>        443/TCP                  57m
# kubernetes-dashboard   service/kubernetes-dashboard-metrics-scraper   ClusterIP   10.107.37.3      <none>        8000/TCP                 57m
# kubernetes-dashboard   service/kubernetes-dashboard-web               ClusterIP   10.101.199.251   <none>        8000/TCP                 57m
#
# NAMESPACE     NAME                        DESIRED   CURRENT   READY   UP-TO-DATE   AVAILABLE   NODE SELECTOR            AGE
# kube-system   daemonset.apps/kube-proxy   1         1         1       1            1           kubernetes.io/os=linux   24d
#
# NAMESPACE              NAME                                                   READY   UP-TO-DATE   AVAILABLE   AGE
# kube-system            deployment.apps/coredns                                2/2     2            2           24d
# kube-system            deployment.apps/metrics-server                         1/1     1            1           57m
# kubernetes-dashboard   deployment.apps/kubernetes-dashboard-api               1/1     1            1           57m
# kubernetes-dashboard   deployment.apps/kubernetes-dashboard-auth              1/1     1            1           57m
# kubernetes-dashboard   deployment.apps/kubernetes-dashboard-kong              1/1     1            1           57m
# kubernetes-dashboard   deployment.apps/kubernetes-dashboard-metrics-scraper   1/1     1            1           57m
# kubernetes-dashboard   deployment.apps/kubernetes-dashboard-web               1/1     1            1           57m
#
# NAMESPACE              NAME                                                              DESIRED   CURRENT   READY   AGE
# kube-system            replicaset.apps/coredns-55cb58b774                                2         2         2       24d
# kube-system            replicaset.apps/metrics-server-869cd9f57                          1         1         1       57m
# kubernetes-dashboard   replicaset.apps/kubernetes-dashboard-api-8c47764c                 1         1         1       57m
# kubernetes-dashboard   replicaset.apps/kubernetes-dashboard-auth-86789567b4              1         1         1       57m
# kubernetes-dashboard   replicaset.apps/kubernetes-dashboard-kong-78fd98d579              1         1         1       57m
# kubernetes-dashboard   replicaset.apps/kubernetes-dashboard-metrics-scraper-6c8d6bb74d   1         1         1       57m
# kubernetes-dashboard   replicaset.apps/kubernetes-dashboard-web-86495b6c8f               1         1         1       57m
